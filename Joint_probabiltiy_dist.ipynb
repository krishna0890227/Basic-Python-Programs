# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import math

# %%
n= 1000
x=abs(np.random.randn(n))*5
y= np.random.randn(n)**2

# %%
fig, ax =plt.subplots()
ax.set_aspect("equal")
hist, xbins, ybins, im =ax.hist2d(x, y, bins=range(6))

# %%
fig, ax = plt.subplots()
ax.set_aspect("equal")
hist, xbins, ybins, im=ax.hist2d(x, y, bins=range(6))

# %%
hist
# Out:
# array([[116.,  28.,   9.,   9.,   8.],
#        [ 97.,  26.,   9.,   4.,   4.],
#        [105.,  27.,  12.,   7.,   4.],
#        [ 84.,  22.,  10.,   4.,   4.],
#        [ 71.,  17.,  11.,   3.,   4.]])

# %%
sns.set()
sns.jointplot(x,y, kind='kde', color=[.8, .3, .9]).plot_joint(sns.kdeplot)
plt.xlabel('x')
plt.ylabel('$x^2$')
plt.show()
# Out:
# C:\Users\Krishna\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.set()

sns.jointplot(x, y, kind='kde', color=[.8, .3, .9]).plot_joint(sns.kdeplot)
plt.xlabel('x')
plt.ylabel('$x^2$')
plt.show()

# %%
number_sample=10000
inner_area, outer_area=0, 0
for i in range(number_sample):
    X=np.random.uniform(0, 1)
    y=np.random.uniform(0, 1)
    if (X**2 + y**2)<1:
        inner_area +=1
    
    outer_area +=1
        
print("The computed value of Pi:", 4*(inner_area/float(outer_area)))
# Out:
# The computed value of Pi: 3.1592

# %%
from scipy.stats import rv_histogram
x=np.random.random(10000)
r=rv_histogram(np.histogram(x, bins=100))
r.pdf(np.linspace(0, 1, 10))
# Out:
# array([0.        , 0.96005239, 0.96005239, 0.97005294, 1.02005567,
#        1.10006003, 1.12006113, 1.03005621, 0.98005348, 0.        ])

# %%
# Generate the Gaussian signal with mean 100 variance 10. 

mu, sigma=200, 10
s=np.random.normal(mu, sigma, 20)
s1=np.random.normal(mu+3*sigma, sigma, 20)

# %%
import matplotlib.pyplot as plt
plt.plot(s, 'b--')
plt.plot(s1, 'r-')
plt.xlim(0, 20)
plt.ylim(0, 300)
plt.show()

# %%
from matplotlib.mlab import bivariate_normal
from mpl_toolkits.mplot3d import Axes3D
x=np.linspace(0, 200, 200) # create a mesh of 200 x-ponts
y=np.linspace(0, 50, 200) # create a mesh of  200 y-points
mu_x=np.mean(x)
mu_y=np.mean(y)/2
sigma_x=np.std(x)
sigma_y=np.std(y)/2
X, Y= np.meshgrid(x, y)
Z=bivariate_normal(X, Y, sigma_x, sigma_y, mu_x, mu_y)
fig=plt.figure()
ax = fig.gca(projection='3d')
ax.plot_surface(X, Y, Z, cmap='Reds', linewidth=0, antialiased=True, zorder=0.5)
plt.show()
# Out:
# C:\Users\Krishna\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: MatplotlibDeprecationWarning: The bivariate_normal function was deprecated in Matplotlib 2.2 and will be removed in 3.1.
#   # Remove the CWD from sys.path while we load stuff.

# %%
from matplotlib.mlab import bivariate_normal
from mpl_toolkits.mplot3d import Axes3D
x=np.linspace(0, 200, 200)
y=np.linspace(0, 50, 200)
mu_x=np.mean(x)
mu_y=np.mean(y)
sigma_x=np.std(x)
sigma_y=np.std(y)
X, Y =np.meshgrid(x, y)
Z=bivariate_normal(X, Y, sigma_x, sigma_y, mu_x, mu_y)

fig=plt.figure()
ax=fig.gca(projection='3d')
ax.plot_surface(X, Y, Z, cmap='Reds', linewidth=0, antialiased=True, zorder=0.5)
plt.show()
# Out:
# C:\Users\Krishna\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: MatplotlibDeprecationWarning: The bivariate_normal function was deprecated in Matplotlib 2.2 and will be removed in 3.1.
#   # Remove the CWD from sys.path while we load stuff.

# %%
import numpy as np
from scipy.io import wavfile
import matplotlib.pyplot as plt

time=np.arange(0, 100, 1)
xx=np.random.uniform(0, 0.95, 100)
yy=np.random.uniform(0., 0.85, 100)
zz=[]

for i in range(0, len(xx)-3):
    con_output=np.convolve(yy[i:i+3], xx[i:i+3], 'valid')
    zz.append(con_output)

plt.plot(xx, 'r-')
plt.plot(yy, 'b--')
plt.plot(zz, 'k-.')
plt.show()

# %%
import seaborn as sns
sns.set()

sns.jointplot(amplitude, amp2, kind='kde', color=[.8, .3, .9]).plot_joint(sns.kdeplot)
# Out:
# C:\Users\Krishna\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
amp3=np.convolve(amplitude, amp2, 'same')
amp4=a

# %%
from random import seed
from random import random
import matplotlib.pyplot as plt
seed(1)
random_walk=list()
random_walk.append(-1 if random() <0.5 else 1)
for i in range(1, 1000):
    movement= -1 if random()<0.5 else 1
    value=random_walk[i-1] + movement
    random_walk.append(value)

plt.plot(random_walk)
plt.show()

# %%
from random import seed
from random import random
import matplotlib.pyplot as plt
seed(1)
random_walk=list()
random_walk.append(-1 if random() < 0.5 else 1)
for i in range(1, 1000):
    movement= -1 if random()<0.5 else 1
    value=random_walk[i-1] + movement
    random_walk.append(value)

plt.plot(random_walk)
plt.show()

# %%
random_walk=np.array(random_walk)
upper_limit= random_walk.mean() + ( random_walk * random_walk.std()/np.sqrt(1000))

# %%
lower_limit=random_walk.mean() - ( random_walk * random_walk.std()/np.sqrt(1000))

# %%
plt.plot(x, y)
plt.show()

# %%
from random import seed
from random import random
import matplotlib.pyplot as plt
seed(1)
random_walk=list()
random_walk.append(-1 if random() < 0.5 else 1)
for i in range(1, 1000):
    movement= -1 if random()<0.5 else 1
    value=random_walk[i-1] + movement
    random_walk.append(value)

x=np.linspace(0, 1000, 1000)
y= random_walk
ci=1.96 * np.std(y)/np.mean(y)
fig, ax=plt.subplots()
ax.plot(x, y)
ax.fill_between(x, (y-3*ci), (y+3*ci), color='r', alpha=.5)

# %%
from scipy import optimize
def f(x):
    print(x)
    return -np.exp(-(-x-0.7)**2)
result=optimize.minimize_scalar(f)
print(result.success)
print(result.x)
# Out:
# 0.0
# 1.0
# -1.618034
# 0.0
# -0.618033974844
# -0.9999999844527367
# -0.682885972817485
# -0.7015305389833855
# -0.7000311041347745
# -0.6999998960644431
# -0.6999999999806387
# -0.6999999896106387
# -0.7000000103506386
# True
# -0.6999999999806387

# %%
def f(x):
    return 0.5*(1-x[0])**2 + (x[1]-x[0]**2)**2
optimize.minimize(f, [2, -1], method="CG")
# Out:
#      fun: 1.6485258037174643e-11
#      jac: array([-6.15005779e-06,  2.53702478e-07])
#  message: 'Optimization terminated successfully.'
#     nfev: 108
#      nit: 13
#     njev: 27
#   status: 0
#  success: True
#        x: array([0.99999426, 0.99998864])

# %%
def jacobian(x):
    return np.array((-2*.5*(1 - x[0]) - 4*x[0]*(x[1] - x[0]**2), 2*(x[1] - x[0]**2)))
optimize.minimize(f, [2, -1], method="CG", jac=jacobian)
# Out:
#      fun: 1.0912121832428475e-11
#      jac: array([-5.25283406e-06,  2.92893688e-07])
#  message: 'Optimization terminated successfully.'
#     nfev: 27
#      nit: 13
#     njev: 27
#   status: 0
#  success: True
#        x: array([0.99999533, 0.99999081])

# %%
def pinball_1(y_true, y_pred):
    loss = 0.1
    with tf.Session() as sess:
        y_true = sess.run(y_true)
        y_pred = sess.run(y_pred)
    y_pin = np.zeros((len(y_true), 1))
    y_pin = tf.placeholder(tf.float32, [None, 1])
    for i in range((len(y_true))):
        if y_true[i] >= y_pred[i]:
            y_pin[i] = loss * (y_true[i] - y_pred[i])
        else:
            y_pin[i] = (1 - loss) * (y_pred[i] - y_true[i])
    pinball = tf.reduce_mean(y_pin, axis=-1)
    return K.mean(pinball, axis=-1)

sgd = SGD(lr=0.1, clipvalue=0.5)
model.compile(loss=pinball_1, optimizer=sgd)
model.fit(Train_X, Train_Y, nb_epoch=10, batch_size=20, verbose=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-a917a6477717> in <module>
#      14     return K.mean(pinball, axis=-1)
#      15
# ---> 16 sgd = SGD(lr=0.1, clipvalue=0.5)
#      17 model.compile(loss=pinball_1, optimizer=sgd)
#      18 model.fit(Train_X, Train_Y, nb_epoch=10, batch_size=20, verbose=2)
#
# NameError: name 'SGD' is not defined
