# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.mlab import bivariate_normal
from mpl_toolkits.mplot3d import Axes3D
x=np.linspace(0, 200, 200) # create a mesh of 200 x-ponts
y=np.linspace(0, 50, 200) # create a mesh of  200 y-points
mu_x=np.mean(x)
mu_y=np.mean(y)/2
sigma_x=np.std(x)
sigma_y=np.std(y)/2
X, Y= np.meshgrid(x, y)
Z=bivariate_normal(X, Y, sigma_x, sigma_y, mu_x, mu_y)
fig=plt.figure()
ax = fig.gca(projection='3d')
ax.plot_surface(X, Y, Z, cmap='Reds', linewidth=0, antialiased=True, zorder=0.5)
plt.show()
# Out:
# C:\Users\Krishna\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: MatplotlibDeprecationWarning: The bivariate_normal function was deprecated in Matplotlib 2.2 and will be removed in 3.1.
#   if sys.path[0] == '':

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.mlab import bivariate_normal
from mpl_toolkits.mplot3d import Axes3D
x=np.linspace(0, 200, 200) # create a mesh of 200 x-ponts
y=np.linspace(0, 50, 200) # create a mesh of  200 y-points
mu_x=np.mean(x)
mu_y=np.mean(y)
sigma_x=np.std(x)
sigma_y=np.std(y)
X, Y= np.meshgrid(x, y)
Z=bivariate_normal(X, Y, sigma_x, sigma_y, mu_x, mu_y)
fig=plt.figure()
ax = fig.gca(projection='3d')
ax.plot_surface(X, Y, Z, cmap='Reds', linewidth=0, antialiased=True, zorder=0.5)
plt.show()
# Out:
# C:\Users\Krishna\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: MatplotlibDeprecationWarning: The bivariate_normal function was deprecated in Matplotlib 2.2 and will be removed in 3.1.
#   if sys.path[0] == '':
